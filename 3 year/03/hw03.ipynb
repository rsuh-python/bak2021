# %% [markdown]
# #### Задача 1.
#
# У нас есть (любой) текст, в котором встречаются целые числа. Числа могут быть отрицательными, тогда между минусом и числом нет никакого другого знака. Напишите программу, которая все числа увеличит на единицу (причем 34 должно превратиться в 35, а -34 - в -33). Нельзя пользоваться циклами!

# %%
# your code here

# %% [markdown]
# #### Задача 2 (2 балла).
#
# Напишите программу - телефонный справочник. Программа при запуске должна проверять, есть ли у нее база данных (используйте os.path.exists()); в бесконечном цикле программа запрашивает, что хочет сделать пользователь, у него есть выбор: искать номер по фамилии, добавить новый номер, сохранить базу и выйти. Соответственно, вне цикла у вас должно быть три функции: функция поиска номера (сама база, очевидно, хранится в виде словаря), функция добавления нового номера и функция сохранения базы данных, в которой наш словарик с номерами будет записываться в файл (можно в .json). Когда человек хочет добавить новый номер, программа должна проверять, ввел ли он номер в формате 0 000 000 00 00, и если нет, то ругаться. Здесь нужно использовать fullmatch.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# В папке лежит файл google.json (там содержатся 50 твитов аккаунта GoogleRussia). Считайте этот файл с помощью модуля pandas. Посмотрите, какие там есть колонки, попытайтесь понять, что они означают и какие могут быть важными. Проверьте, все ли твиты на русском языке. Посчитайте, сколько в среднем получил лайков каждый твит.
#
# \* Дополнительное задание на 1 балл:
#
# С помощью регулярных выражений удалите из твитов все хештеги (#ДеньУчителя) и обращения к пользователю (@GoogleRussia).

# %%
# your code here
